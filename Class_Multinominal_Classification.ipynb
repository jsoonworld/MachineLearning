# %% [markdown]
# ##Binary(Pass/fail) 분류가 아닌 N개의 Class 분류 문제
#
# * Multinominal Classification VS Logistic Regression
#
# ##Softmax
# * Classifier에서 나온 값을 0 ~ 1사이 값을 가지는 확률 분포 값으로 변경
#
# ##Cross Entropy Loss
# * 예측한 확률분포값과 실제 정답을 비교 해서 손실값 산정
# * 두 확률분포의 거리(차이)를 계산하는 방법

# %% [markdown]
# ![스크린샷 2022-12-05 오후 8.31.54.png](data:image/png;base64,...)
