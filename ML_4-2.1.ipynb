# %% [markdown]
# ##Stochastic Gradient Descent (확률적 경사 하강법)
# 대표적인 점진적인 학습/ 온라인 학습
#
# ##epoch
# 확률적 경사 하강법에서 훈련 세트를 한 번 모두 사용하는 과정.
#
# ##minibatch gradient descent
# 여러개의 샘플을 사용해 경사 하강법을 수행하는 방식
#
# ##loss function (손실 함수)
#
# cost function은 훈련 세트에 있는 모든 샘플에 대한 손실 합.
#
# loss function은 샘플 하나에 대한 손실
#
#
# ##Logistic loss function or binary cross-entropy loss function
#
# 확률로 표현해 연속적인 손실 함수로 만들기
#
# 로그 함수는 0에 가까울수록 아주 큰 음수가 되기 때문에 손실을 아주 크게 만들어
# 모델에 큰 영향을 미칠 수 있다.
#
# ##cross-entropy loss function

# %%
import pandas as pd
fish = pd.read_csv('https://bit.ly/fish_csv_data')
fish_input = fish[['Weight','Length','Diagonal','Height','Width',]].to_numpy()
fish_target = fish['Species'].to_numpy()

# %%
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(fish_input, fish_target, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(train_input)
train_scaled= ss.transform(train_input)
test_scaled = ss.transform(test_input)

# %%
from sklearn.linear_model import SGDClassifier

# %%
sc = SGDClassifier(loss='log', max_iter =10, random_state=42)
sc.fit(train_scaled, train_target)
print(sc.score(train_scaled, train_target))
print(sc.score(test_scaled, test_target))
# Out:
# 0.773109243697479
# 0.775
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:700: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,

# %%
sc.partial_fit(train_scaled, train_target)
print(sc.score(train_scaled, train_target))
print(sc.score(test_scaled, test_target))
# Out:
# 0.8151260504201681
# 0.85

# %% [markdown]
# ##에포크와 과대/과소적합
