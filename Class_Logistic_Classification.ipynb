# %% [markdown]
# ##Logistic Regression = Logistic Classification
#
# ##정수가 아닌 Binary(Pass/fail)분류 문제
#
# ##Binary Classification
#
# ##Multinominal Classification
#
# ##Logistic Regression
#
# ##Linear Regression으로 Classification 해보기.
#
# ##Sigmoid Function - > 어떤 값이든 0 ~ 1 사이로 변경해줌
#
# Non-linear decision boundary를  보면 Linear로 분류가 안 될 수 있다.
#
# ##Logistic Classification의 Cost 함수를 MSE로 해보면
#
# 1차원 함수에 MSE를 하면 Cost값은 2차원 함수로 표현됨.
# 하지만 1차원 함수에 Sigmoid를 취하면?
#
# ##Logistic Classification의 Cost함수는 어떻게 정의할까.
#
# Cost 함수의 목적에 충실하자
# * 예측이 틀릴 경우 Cost = 매우 높음
# * 예측이 맞을 경우 Cost =0
#
# ##Cost값을 기반으로 Gradient Decent 알고리즘을 이용해 최적의 파라미터 W값을 찾자.

# %% [markdown]
# ![스크린샷 2022-12-05 오후 8.25.44.png](data:image/png;base64,...)
